# %% [markdown]
# ### Why we are only using 2018 and 2019 data
# Numbers of flight delays as well as overall flights are drastically reduced.
# TODO: Reason this

# %%
years = ['2018', '2019', '2020', '2021', '2022']
num_entries = []

for year in years:
    df = pd.read_parquet(f"{root}flights_{year}.parquet")
    num_entries.append(len(df))

del df # Clear memory

plt.bar(years, num_entries)
plt.title('Number of Entries by Year')
plt.xlabel('Year')
plt.ylabel('Number of Entries')
plt.show()
